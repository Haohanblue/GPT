# %% [markdown]
# # Functions and template

# %%
ZHIPUAI_API_KEY = "your zhipu ai api key"

# %%
import re
import json
from zhipuai import ZhipuAI
from langchain.prompts import PromptTemplate
import pandas as pd

# %%
def zhipu_chat_complete(prompt, model = "glm-4-air"):
    """
    使用智谱的glm模型进行对话"""
    # 初始化智谱的API客户端
    client = ZhipuAI(api_key=ZHIPUAI_API_KEY)
    # 调用智谱的API进行对话
    response = client.chat.completions.create(
        model = model,
        messages=[
            {
                "role": "user",
                "content": prompt
            }
        ],
        temperature=0.1,
        max_tokens=1024
    )
    # 返回智谱的API的响应结果
    answer = response.choices[0].message.content
    return answer

# %%
def extract_sentiments_json(text):
    # Regular expression to find JSON object
    json_pattern = r'\{.*?\}'
    # Find all JSON objects in the text
    json_matches = re.findall(json_pattern, text, re.DOTALL)
    # Parse the JSON strings
    try:
        json_data = json.loads(json_matches[0])
        if ("positive" in json_data) and ("negative" in json_data) and ("neutral" in json_data):
            return json_matches[0]
        else:
            return None
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e}")
        return None

# %%
prompt_template_string = """
Consider the message on a listing firm, please extract the sentiments (hold, down, neutral) distribution (i.e., probabilities of its sentiments) from the message.\ 
The sum of probabilities of sentiments must be equal to 1.

The message:
{message}

Workflow: 
- First step, please pay special attention to the following points one by one, and at the same time evaluate the sentiments distribution of the message.
Attention 1: Please pay special attention to any irrealis mood used.
Attention 2: Please pay special attention to any rhetorics (sarcasm, negative assertion, etc.) used.
Attention 3: Please focus on the speaker sentiment, not a third party.
Attention 4: Please focus on the stock ticker/tag/topic, not other entities.
Attention 5: Please pay special attention to the time expressions, prices, and other unsaid facts.
- Second step, Based on the initial evaluations in the first step, make the final overall evaluation of the sentiments (positive, negative, neutral) distribution.

Output requirements:
- Output the sentiments distribution in the second step strictly following JSON format with keys of positive, negative, and neutral.
- The sum of probabilities of sentiments must be equal to 1. 
"""

# %% [markdown]
# # test

# %%
prompt_template = PromptTemplate(template= prompt_template_string, input_variables=["message"])
message = "可怜的投资者往往还在期待像过去那样上天，有机会不逃跑可能就是上西天[微笑]，真正好的你发现不了，你拿到的往往就是地雷"
prompt = prompt_template.format(message = message)

# %%
print(prompt)
# Out:
# Consider the message on a listing firm, please extract the sentiments (hold, down, neutral) distribution (i.e., probabilities of its sentiments) from the message.\
# The sum of probabilities of sentiments must be equal to 1.
#
# The message:
# 可怜的投资者往往还在期待像过去那样上天，有机会不逃跑可能就是上西天[微笑]，真正好的你发现不了，你拿到的往往就是地雷
#
# Workflow:
# - First step, please pay special attention to the following points one by one, and at the same time evaluate the sentiments distribution of the message.
# Attention 1: Please pay special attention to any irrealis mood used.
# Attention 2: Please pay special attention to any rhetorics (sarcasm, negative assertion, etc.) used.
# Attention 3: Please focus on the speaker sentiment, not a third party.
# Attention 4: Please focus on the stock ticker/tag/topic, not other entities.
# Attention 5: Please pay special attention to the time expressions, prices, and other unsaid facts.
# - Second step, Based on the initial evaluations in the first step, make the final overall evaluation of the sentiments (positive, negative, neutral) distribution.
#
# Output requirements:
# - Output the sentiments distribution in the second step strictly following JSON format with keys of positive, negative, and neutral.
# - The sum of probabilities of sentiments must be equal to 1.

# %%
p = zhipu_chat_complete(prompt=prompt, model = "GLM-4-Air")

# %%
print(p)
# Out:
# To analyze the given message and extract the sentiment distribution, let's break down the message according to the attention points provided:
#
# Message: "可怜的投资者往往还在期待像过去那样上天，有机会不逃跑可能就是上西天[微笑]，真正好的你发现不了，你拿到的往往就是地雷"
#
# Translation: "Poor investors often still expect to soar to the heavens as in the past; if they don't escape at the opportunity, it might be going to the other world [smile]. You can't find the truly good ones, what you often end up with is a landmine."
#
# Attention 1: The irrealis mood is present in the phrase "if they don't escape at the opportunity, it might be going to the other world," which implies a hypothetical scenario with a negative outcome.
#
# Attention 2: The use of "上西天" (going to the other world) with the smiley emoji "[微笑]" can be interpreted as sarcasm, indicating a negative sentiment. The phrase "what you often end up with is a landmine" is a negative assertion about the outcomes for investors.
#
# Attention 3: The speaker seems to express a negative sentiment towards the situation for investors.
#
# Attention 4: The focus is on the stock investments ("poor investors," "going to the heavens," "landmine"), and the sentiment is negative regarding these investments.
#
# Attention 5: There are no explicit time expressions, prices, or unsaid facts that would change the sentiment analysis.
#
# Based on the initial evaluation, the sentiment of the message is predominantly negative. The speaker is expressing a critical view of the investment outcomes for "poor investors," suggesting that they are unlikely to find good opportunities and are instead likely to encounter negative outcomes.
#
# Now, for the final overall evaluation of the sentiments distribution:
#
# ```json
# {
#   "positive": 0.0,
#   "negative": 0.9,
#   "neutral": 0.1
# }
# ```
#
# The sentiment distribution is as follows:
# - Positive sentiment is not present in the message.
# - Negative sentiment is strong, accounting for 90% of the sentiment distribution.
# - Neutral sentiment is minimal, accounting for 10% of the sentiment distribution, as there is a slight hint of a neutral observation without a strong positive or negative connotation in the phrase "poor investors often still expect."
#
# The sum of probabilities is 1.0, satisfying the requirement.

# %%
p_d = json.loads(extract_sentiments_json(p))

# %%
p_d
# Out:
# {'positive': 0.1, 'negative': 0.8, 'neutral': 0.1}

# %%
def label_sentiment(message):
    prompt_template = PromptTemplate(template= prompt_template_string, input_variables=["message"])
    prompt = prompt_template.format(message = message)
    p = zhipu_chat_complete(prompt = prompt, model = "GLM-4-Air")
    sentiment_dict = json.loads(extract_sentiments_json(p))
    # 获取情感倾向的最大值
    max_sentiment = max(sentiment_dict.values())
    # 判断情感倾向并返回相应的值
    if sentiment_dict['positive'] == max_sentiment:
        return 1
    elif sentiment_dict['negative'] == max_sentiment:
        return -1
    else:
        return 0

# %%
label_sentiment(message)
# Out:
# -1

# %% [markdown]
# # data

# %%
# 读取CSV文件
df = pd.read_csv('labeldata.csv')
# 查看数据的前几行
df.head()
# Out:
#   用户股吧年龄          用户昵称             个股名称                  评论标题  \
# 0   5.8年     星辰大海12639  浦发银行(600000.sh)      业绩不错，为啥跌的如此厉害亏大了
# 1   8.8年           高天运  浦发银行(600000.sh)                    愉快
# 2   6.9年         面包二米粥  浦发银行(600000.sh)       浦发是庄股了！每天成交量好少！
# 3  10.3年  股友O9700I7223  浦发银行(600000.sh)  有没有人想过，过了3300，赚一笔就跑的
# 4     7年      股市扁鹊8956  浦发银行(600000.sh)                 开盘5分钟
#
#                                                 评论内容              发帖时间  标签  \
# 0                                 业绩不错，为啥跌的如此厉害[亏大了]  2019/10/30 13:19  负向
# 1                                                 愉快   2016/7/28 17:49  正向
# 2                                    浦发是庄股了！每天成交量好少！    2016/12/4 9:33  负向
# 3  是不是和2015年6月份时候，认为大盘5100还要上攻，是同样的死法？ 历史总是惊人的相同[大笑]   2017/4/19 10:30  中性
# 4  1：股指期货：翻红上冲中，较好。 2：沪深两市：两市纷纷高开，主板和创业板暂时持平，盘中预计...    2016/2/16 9:53  中性
#
#    label
# 0     -1
# 1      1
# 2     -1
# 3      0
# 4      0

# %%
df.shape
# Out:
# (12000, 8)

# %%
sampled_data = df.sample(n=50)

# %%
sampled_data
# Out:
#       用户股吧年龄              用户昵称             个股名称  \
# 3985    6.4年              匈奴女人  海尔智家(600690.sh)
# 3053    3.9年               神人昶  复星医药(600196.sh)
# 7275    6.7年             华尔街巨富  中国石油(601857.sh)
# 7302    2.7年             真的土猩猩  中国石油(601857.sh)
# 4021    7.3年              湘水稳涨  海尔智家(600690.sh)
# 9065    6.8年             民间炒股者  兴业银行(601166.sh)
# 9153   12.7年         暗色调252277  兴业银行(601166.sh)
# 1010    3.7年            爱德华爱投资  上汽集团(600104.sh)
# 4635    7.8年         elliesa88  中国中免(601888.sh)
# 10802     3年          股友E9mu9l  三安光电(600703.sh)
# 8099    2.7年          股友2taoLz  中信证券(600030.sh)
# 9904    6.2年          LUCKY333  中国太保(601601.sh)
# 3650    5.5年              好贵经济  恒生电子(600570.sh)
# 6228    7.1年  n142952906722957  恒瑞医药(600276.sh)
# 11334   6.6年           笑看风云淡66  中国人寿(601628.sh)
# 2713    5.4年          英明神武地小红豆  伊利股份(600887.sh)
# 11500   7.2年              想富穷到  中国人寿(601628.sh)
# 3032      8年           啥也不懂随便买  复星医药(600196.sh)
# 861     8.7年           沪TV3849  招商银行(600036.sh)
# 9099    7.1年        cobain2326  兴业银行(601166.sh)
# 11577     6年           北京路1409  中国人寿(601628.sh)
# 2191    6.2年          股友NPkfnz  用友网络(600588.sh)
# 3595    8.6年              慢牛快涨  通威股份(600438.sh)
# 5151    5.1年          股友YUmcp1  民生银行(600016.sh)
# 7652    7.5年           纳豆子4317  上海机场(600009.sh)
# 11429  10.2年              高志宏1  中国人寿(601628.sh)
# 7639    7.1年    ahaisht1236422  上海机场(600009.sh)
# 2964    7.7年          股友55uVWE  伊利股份(600887.sh)
# 10216   4.7年           百家号面皮娱乐  贵州茅台(600519.sh)
# 6266    5.8年          股友czMwTs  恒瑞医药(600276.sh)
# 11656   7.4年          年年翻倍7768  紫金矿业(601899.sh)
# 2297    4.5年      股友SPiaZV0221  用友网络(600588.sh)
# 1216    7.9年            小花4441  上汽集团(600104.sh)
# 444     4.8年       王者荣耀0018175  中国石化(600028.sh)
# 7365    2.4年        xf1117haha  中国石油(601857.sh)
# 7438    7.5年           天问71405  中国石油(601857.sh)
# 29      5.6年         叉济年449174  浦发银行(600000.sh)
# 10268   8.5年          萍水相逢1122  海螺水泥(600585.sh)
# 10011  11.4年      zhutangxueli  贵州茅台(600519.sh)
# 3104      3年          股友OaQboz  复星医药(600196.sh)
# 6303      5年        黑金刚abc9449  中国神华(601088.sh)
# 1736    6.8年           HX3F2U9  山东黄金(600547.sh)
# 2206    7.2年              林峰哥哥  用友网络(600588.sh)
# 9826   13.8年             ahckh  中国太保(601601.sh)
# 4893    6.5年        autoupdate  中国中免(601888.sh)
# 9174    5.9年           tjbhhmz  兴业银行(601166.sh)
# 1179    5.7年              究竟了义  上汽集团(600104.sh)
# 11940   6.4年  dfcflvbu20164363  浦发银行(600000.sh)
# 11115   6.6年            江苏深爱科技  海通证券(600837.sh)
# 2877    7.9年            你这个大聪明  伊利股份(600887.sh)
#
#                                            评论标题  \
# 3985                                      明天满上！
# 3053                                  ！这是要跌停卧槽！
# 7275                         关注万达电影，今天有好戏！开盘进入！
# 7302                                2点了，等待万手哥出现
# 4021       吵什么，这肯定利空呀总不会是利好吧，影响多大星期一收盘就知道了，不说了，
# 9065                                  后市冲高后仍有振荡
# 9153                      福成股份：收购牧场剥离冗余陵园业务前景广阔
# 1010   手握千亿未分配利润，这可能才是近期杀入的大户的决心吧！周期股就是得耐心的等。等到
# 4635                                    涨两天跌半个月
# 10802                               快点跌，别犹豫使劲砸。
# 8099                中信你等着包销邮储银行那些弃购，看看你年底业绩如何打脸
# 9904                                     下周还有动力
# 3650                                       操纵股价
# 6228                           市盈率都70多倍了，还好意思上涨
# 11334                    13手砸下7个价位，还有比这更好的做空工具么
# 2713                                 给个机会，红了我就出
# 11500                               今天忽悠了不少散户接盘
# 3032                  为什么沪港通一直在抛复星医药，而恒瑞确实一直在加仓
# 861                                 安邦保险被保监会接管.
# 9099                                     高处不胜寒！
# 11577                                  对你太失望，走人
# 2191                         2018年市值将超500亿，立此为证
# 3595                                       阴跌开始
# 5151                                     放量了，好事
# 7652                                      念武陵人远
# 11429                    阿！受不了！别人大涨，你小涨，别人小跌你大跌
# 7639                     煤炭钢铁白马见顶，主板一周后拐头向下，向中小
# 2964                                      又要举牌了
# 10216                     茅台价还是高，调到400多大盘才有可能稳住
# 6266                         闪讯股市常青树恒瑞医药股价九循环见底
# 11656                                        连涨
# 2297                            兄弟姐妹们别慌卖了上到25在卖
# 1216   二月二龙抬头凤摆尾。中信24.44收午盘。冥冥之中的预试，就是预试本轮反弹见顶了
# 444                     000905厦门港务金砖会议概念，后面有大行情
# 7365                  20年前巴菲特1块买入，20年后4块买入复制巴菲尔
# 7438                         什么时候中石油闪崩，谁有本事砸跌停，
# 29                                     本没什么本没什么
# 10268                      忍不住上来说句，主力吃了老鼠药，等死呢。
# 10011                         跌倒320元，还有13倍的市盈率。
# 3104                           青蒿素上中央一台新闻联播了！！！
# 6303                  辛辛苦苦大半年，一夜回到解放前！亏大了亏大了亏大了
# 1736                             今天山东黄金应该涨停板了吧！
# 2206                                 买的人少，拉不起来的
# 9826                      一季报出来还敢拉，就只能说明庄家太无耻了！
# 4893                                    而是不要险资做
# 9174          请问2015年报的15.1的净资产是如何算出来的，请牛人具体分析下
# 1179                                 降低关税利好上汽微笑
# 11940                                     不错，要涨
# 11115                                      明天买他
# 2877                       Westland股东批准伊利收购公司提案
#
#                                                     评论内容              发帖时间  \
# 3985                                               明天满上！   2018/5/27 21:37
# 3053                                          ！这是要跌停?卧槽！    2019/1/2 10:49
# 7275                                  关注万达电影，今天有好戏！开盘进入！    2017/6/29 7:25
# 7302                                         2点了，等待万手哥出现   2019/9/23 14:01
# 4021              吵什么，这肯定利空呀总不会是利好吧，影响多大星期一收盘就知道了，[不说了]，    2018/5/27 5:10
# 9065                                           后市冲高后还有振荡   2016/6/28 17:15
# 9153                                              今晚消息汇总   2017/7/29 23:09
# 1010   手握千亿未分配利润，这可能才是近期杀入的大户的决心吧！周期股就是得耐心的等。等到经济起缓，世...   2019/5/27 14:29
# 4635                                             涨两天跌半个月   2018/6/13 17:52
# 10802                                        快点跌，别犹豫使劲砸。    2019/7/4 10:16
# 8099                         中信你等着包销邮储银行那些弃购，看看你年底业绩如何打脸  2019/11/30 23:24
# 9904                                              下周还有动力   2018/8/24 14:32
# 3650                        在中国，男人喝茅台，女人抹珀莱，成为高档时尚的代表理念。   2018/8/21 16:16
# 6228                                   市盈率都70多倍了，还好意思上涨？   2018/5/31 12:59
# 11334                             13手砸下7个价位，还有比这更好的做空工具么    2018/8/14 9:35
# 2713                                          给个机会，红了我就出   2019/5/29 13:52
# 11500                                        今天忽悠了不少散户接盘    2016/8/1 15:09
# 3032                           为什么沪港通一直在抛复星医药，而恒瑞确实一直在加仓    2018/3/16 9:14
# 861                                                  利空.    2018/2/23 9:44
# 9099                                              高处不胜寒！     2018/7/9 9:31
# 11577                                           对你太失望，走人   2017/11/8 15:53
# 2191                                  2018年市值将超500亿，立此为证  2017/12/22 10:13
# 3595                                                阴跌开始   2019/5/17 10:30
# 5151                                     利空消息出了， 差不多就是时机   2017/4/18 10:34
# 7652                                               念武陵人远   2017/7/13 17:08
# 11429                             阿！受不了！别人大涨，你小涨，别人小跌你大跌    2017/7/6 10:43
# 7639                                          各种费用也会涨；第二    2017/8/7 17:28
# 2964                                               又要举牌了   2016/10/25 9:42
# 10216                              茅台价还是高，调到400多大盘才有可能稳住   2018/8/30 18:57
# 6266   股市“常青树”郭海培，恒瑞医药600276股价九循环今天见底，最后买入机会指标kdj即将金叉...  2018/12/19 10:55
# 11656                                                 连涨  2019/10/28 20:57
# 2297                                     兄弟姐妹们别慌卖了上到25在卖    2018/6/4 13:20
# 1216   二月二龙抬头凤摆尾。中信24.44收午盘。冥冥之中的预试，就是预试本轮反弹见顶了。今天是分出...    2019/3/8 12:50
# 444                              000905厦门港务金砖会议概念，后面有大行情   2017/7/21 14:52
# 7365                  A股中石油5块以下降形成本轮熊市的大底，抄底大军可以准备银子捡黄金了  2019/11/11 19:50
# 7438                                  什么时候中石油闪崩，谁有本事砸跌停，   2017/7/13 10:55
# 29                                              本没什么本没什么   2017/3/22 14:38
# 10268                               忍不住上来说句，主力吃了老鼠药，等死呢。   2016/3/18 14:06
# 10011                                        13倍的市盈率比较合理   2018/8/17 14:21
# 3104                                    青蒿素上中央一台新闻联播了！！！   2019/6/17 19:24
# 6303                     辛辛苦苦大半年，一夜回到解放前！[亏大了][亏大了][亏大了]   2018/4/20 13:23
# 1736                                      今天山东黄金应该涨停板了吧！     2018/1/9 3:50
# 2206                                          买的人少，拉不起来的   2018/5/14 14:13
# 9826                               一季报出来还敢拉，就只能说明庄家太无耻了！   2016/4/20 18:18
# 4893                                中国股市的最大问题是优质上市公司实在太少    2017/7/8 14:17
# 9174   单位：亿 每股净资产＝股东权益/总股本（可百度） 数据来源为兴业银行公开的资产负债表，可在网...   2016/12/14 9:03
# 1179                                        降低关税利好上汽[微笑]   2018/5/28 22:21
# 11940                                              不错，要涨    2016/1/1 10:15
# 11115                                               明天买他    2016/5/9 20:45
# 2877   原标题：Westland股东批准伊利收购公司提案 来源：北京商报 　　北京商报讯（记者 钱瑜...    2019/7/4 21:45
#
#        标签  label
# 3985   正向      1
# 3053   负向     -1
# 7275   正向      1
# 7302   中性      0
# 4021   中性      0
# 9065   正向      1
# 9153   中性      0
# 1010   正向      1
# 4635   负向     -1
# 10802  负向     -1
# 8099   负向     -1
# 9904   正向      1
# 3650   负向     -1
# 6228   负向     -1
# 11334  负向     -1
# 2713   正向      1
# 11500  负向     -1
# 3032   中性      0
# 861    负向     -1
# 9099   负向     -1
# 11577  负向     -1
# 2191   正向      1
# 3595   负向     -1
# 5151   正向      1
# 7652   中性      0
# 11429  负向     -1
# 7639   中性      0
# 2964   正向      1
# 10216  正向      1
# 6266   中性      0
# 11656  正向      1
# 2297   正向      1
# 1216   中性      0
# 444    中性      0
# 7365   正向      1
# 7438   负向     -1
# 29     负向     -1
# 10268  负向     -1
# 10011  中性      0
# 3104   正向      1
# 6303   负向     -1
# 1736   正向      1
# 2206   负向     -1
# 9826   负向     -1
# 4893   负向     -1
# 9174   中性      0
# 1179   正向      1
# 11940  正向      1
# 11115  正向      1
# 2877   中性      0

# %%
predicted = []
labels = []

# %%
# 循环获取DataFrame中的数据
import time
total_rows = sampled_data.shape[0]
count = 0
for index, row in sampled_data.iterrows():
    # 读取Name列的内容
    message = row['评论内容']
    # 进行处理
    print(f"message: {message}")
    #time.sleep(1)
    try:
        predicted_label = label_sentiment(message=message)
        print(f"predicted_label: {predicted_label}")
        predicted.append(predicted_label)
        labels.append(row["label"])
        print("acctual label: " + str(row["label"]))
        
        # 打印进度
        current_progress = (count + 1) / total_rows * 100
        count += 1
        print(f"Progress: {current_progress:.2f}%")
    except:
        continue
# Out:
# message: 明天满上！
# predicted_label: 1
# acctual label: 1
# Progress: 2.00%
# message: ！这是要跌停?卧槽！
# predicted_label: -1
# acctual label: -1
# Progress: 4.00%
# message: 关注万达电影，今天有好戏！开盘进入！
# predicted_label: 1
# acctual label: 1
# Progress: 6.00%
# message: 2点了，等待万手哥出现
# predicted_label: 0
# acctual label: 0
# Progress: 8.00%
# message: 吵什么，这肯定利空呀总不会是利好吧，影响多大星期一收盘就知道了，[不说了]，
# predicted_label: -1
# acctual label: 0
# Progress: 10.00%
# message: 后市冲高后还有振荡
# predicted_label: -1
# acctual label: 1
# Progress: 12.00%
# message: 今晚消息汇总
# predicted_label: 1
# acctual label: 0
# Progress: 14.00%
# message: 手握千亿未分配利润，这可能才是近期杀入的大户的决心吧！周期股就是得耐心的等。等到经济起缓，世界局势平稳，到时候肯定是一飞冲天啊！
# predicted_label: 1
# acctual label: 1
# Progress: 16.00%
# message: 涨两天跌半个月
# Error decoding JSON: Expecting property name enclosed in double quotes: line 2 column 21 (char 22)
# message: 快点跌，别犹豫使劲砸。
# predicted_label: -1
# acctual label: -1
# Progress: 18.00%
# message: 中信你等着包销邮储银行那些弃购，看看你年底业绩如何打脸
# predicted_label: -1
# acctual label: -1
# Progress: 20.00%
# message: 下周还有动力
# predicted_label: 0
# acctual label: 1
# Progress: 22.00%
# message: 在中国，男人喝茅台，女人抹珀莱，成为高档时尚的代表理念。
# predicted_label: 0
# acctual label: -1
# Progress: 24.00%
# message: 市盈率都70多倍了，还好意思上涨？
# predicted_label: -1
# acctual label: -1
# Progress: 26.00%
# message: 13手砸下7个价位，还有比这更好的做空工具么
# predicted_label: -1
# acctual label: -1
# Progress: 28.00%
# message: 给个机会，红了我就出
# predicted_label: 1
# acctual label: 1
# Progress: 30.00%
# message: 今天忽悠了不少散户接盘
# predicted_label: -1
# acctual label: -1
# Progress: 32.00%
# message: 为什么沪港通一直在抛复星医药，而恒瑞确实一直在加仓
# predicted_label: 0
# acctual label: 0
# Progress: 34.00%
# message: 利空.
# predicted_label: -1
# acctual label: -1
# Progress: 36.00%
# message: 高处不胜寒！
# predicted_label: -1
# acctual label: -1
# Progress: 38.00%
# message: 对你太失望，走人
# predicted_label: -1
# acctual label: -1
# Progress: 40.00%
# message: 2018年市值将超500亿，立此为证
# predicted_label: 1
# acctual label: 1
# Progress: 42.00%
# message: 阴跌开始
# predicted_label: -1
# acctual label: -1
# Progress: 44.00%
# message: 利空消息出了， 差不多就是时机
# predicted_label: -1
# acctual label: 1
# Progress: 46.00%
# message: 念武陵人远
# predicted_label: 0
# acctual label: 0
# Progress: 48.00%
# message: 阿！受不了！别人大涨，你小涨，别人小跌你大跌
# predicted_label: -1
# acctual label: -1
# Progress: 50.00%
# message: 各种费用也会涨；第二
# predicted_label: -1
# acctual label: 0
# Progress: 52.00%
# message: 又要举牌了
# predicted_label: 1
# acctual label: 1
# Progress: 54.00%
# message: 茅台价还是高，调到400多大盘才有可能稳住
# predicted_label: -1
# acctual label: 1
# Progress: 56.00%
# message: 股市“常青树”郭海培，恒瑞医药600276股价九循环今天见底，最后买入机会指标kdj即将金叉可大胆全仓加融资买入，主力抬轿拉升在即这是二级市场投资者要严重关注。
# predicted_label: 1
# acctual label: 0
# Progress: 58.00%
# message: 连涨
# predicted_label: 1
# acctual label: 1
# Progress: 60.00%
# message: 兄弟姐妹们别慌卖了上到25在卖
# predicted_label: -1
# acctual label: 1
# Progress: 62.00%
# message: 二月二龙抬头凤摆尾。中信24.44收午盘。冥冥之中的预试，就是预试本轮反弹见顶了。今天是分出谁拿现金谁拿套牢票的一天了，。2019.3.8
# predicted_label: -1
# acctual label: 0
# Progress: 64.00%
# message: 000905厦门港务金砖会议概念，后面有大行情
# predicted_label: 1
# acctual label: 0
# Progress: 66.00%
# message: A股中石油5块以下降形成本轮熊市的大底，抄底大军可以准备银子捡黄金了
# predicted_label: 1
# acctual label: 1
# Progress: 68.00%
# message: 什么时候中石油闪崩，谁有本事砸跌停，
# predicted_label: -1
# acctual label: -1
# Progress: 70.00%
# message: 本没什么本没什么
# predicted_label: 0
# acctual label: -1
# Progress: 72.00%
# message: 忍不住上来说句，主力吃了老鼠药，等死呢。
# predicted_label: -1
# acctual label: -1
# Progress: 74.00%
# message: 13倍的市盈率比较合理
# predicted_label: 1
# acctual label: 0
# Progress: 76.00%
# message: 青蒿素上中央一台新闻联播了！！！
# predicted_label: 1
# acctual label: 1
# Progress: 78.00%
# message: 辛辛苦苦大半年，一夜回到解放前！[亏大了][亏大了][亏大了]
# predicted_label: -1
# acctual label: -1
# Progress: 80.00%
# message: 今天山东黄金应该涨停板了吧！
# predicted_label: 1
# acctual label: 1
# Progress: 82.00%
# message: 买的人少，拉不起来的
# predicted_label: -1
# acctual label: -1
# Progress: 84.00%
# message: 一季报出来还敢拉，就只能说明庄家太无耻了！
# predicted_label: -1
# acctual label: -1
# Progress: 86.00%
# message: 中国股市的最大问题是优质上市公司实在太少
# predicted_label: -1
# acctual label: -1
# Progress: 88.00%
# message: 单位：亿 每股净资产＝股东权益/总股本（可百度） 数据来源为兴业银行公开的资产负债表，可在网上自行搜索下载，具体数据可追溯到2003年  2015年9月30日 总股本190.52亿 归属于母公司股东的权益：3024.24 少数股东权益：34.15 股东权益：3058.39 每股净...
# predicted_label: 0
# acctual label: 0
# Progress: 90.00%
# message: 降低关税利好上汽[微笑]
# predicted_label: 1
# acctual label: 1
# Progress: 92.00%
# message: 不错，要涨
# predicted_label: 1
# acctual label: 1
# Progress: 94.00%
# message: 明天买他
# predicted_label: 0
# acctual label: 1
# Progress: 96.00%
# message: 原标题：Westland股东批准伊利收购公司提案 来源：北京商报 　　北京商报讯（记者 钱瑜 姚倩）7月4日，新西兰第二大乳业合作社Westland Co-Operative Dairy Company Limited（以下简称“Westland”）董事局宣布，根据公司条例，伊利收购公司的提案已获股东批准。 　　根据Westland股东投票细节，参与投票的股东共有2494人投赞成票、165人持反对...
# predicted_label: 0
# acctual label: 0
# Progress: 98.00%

# %%
len(labels)
# Out:
# 49

# %%
len(predicted)
# Out:
# 49

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score

# 假设labels是真实标签，predicted_labels是预测结果
labels = labels  # 真实标签
predicted_labels = predicted  # 预测结果

#labels = new_labels  # 真实标签
#predicted_labels = new_predicted  # 预测结果

# 计算准确率
accuracy = accuracy_score(labels, predicted_labels)

# 计算精确度
precision = precision_score(labels, predicted_labels, average='weighted')

# 计算召回率
recall = recall_score(labels, predicted_labels, average='weighted')

# 计算F1分数
f1 = f1_score(labels, predicted_labels, average='weighted')

# 计算混淆矩阵
conf_matrix = confusion_matrix(labels, predicted_labels)

# 计算ROC AUC分数（如果模型输出概率）
# roc_auc = roc_auc_score(labels, predicted_labels, multi_class='ovr')

# 打印结果
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
print(f"Confusion Matrix: {conf_matrix}")
# print(f"ROC AUC: {roc_auc}")
# Out:
# Accuracy: 0.6938775510204082
# Precision: 0.6862244897959183
# Recall: 0.6938775510204082
# F1 Score: 0.6825188547179669
# Confusion Matrix: [[17  2  0]
#  [ 3  5  4]
#  [ 4  2 12]]
